# %% [raw]
# # Villas Real Estate Price analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Data loading

# %%
df=pd.read_csv("/Users/bshryalqrny/Desktop/train_data.csv")
df
# Out:
#           price     neighborhood_name administritive_area           city  \
# 0     1300000.0           Al Munsiyah              Riyadh    East Riyadh
# 1     2500000.0             Al Murjan              Makkah         Jeddah
# 2     1300000.0              Ar Rimal              Riyadh    East Riyadh
# 3     1550000.0            Az Zomorod              Makkah         Jeddah
# 4     1000000.0             Ash Shifa              Riyadh   South Riyadh
# ...         ...                   ...                 ...            ...
# 1412   900000.0                 Dirab              Riyadh   South Riyadh
# 1413   950000.0              Al Awali              Riyadh      Al Riyadh
# 1414  1350000.0  Abhur Ash Shamaliyah              Makkah         Jeddah
# 1415  1600000.0               Al Arid              Riyadh   North Riyadh
# 1416  1850000.0             Al Amanah              Riyadh   North Riyadh
#
#       rooms  bathrooms    sqm  elevator  bool  driver  garden
# ...

# %%
#EDA

# %%
df.head(5)
# Out:
#        price neighborhood_name administritive_area           city  rooms  \
# 0  1300000.0       Al Munsiyah              Riyadh    East Riyadh      4
# 1  2500000.0         Al Murjan              Makkah         Jeddah      5
# 2  1300000.0          Ar Rimal              Riyadh    East Riyadh      5
# 3  1550000.0        Az Zomorod              Makkah         Jeddah      6
# 4  1000000.0         Ash Shifa              Riyadh   South Riyadh      4
#
#    bathrooms    sqm  elevator  bool  driver  garden
# 0          5  240.0         0     0       0       0
# 1          4  309.0         0     1       0       0
# 2          5  300.0         0     0       0       0
# 3          6  312.0         0     0       0       0
# 4          3  300.0         0     0       0       0

# %%
df.tail()
# Out:
#           price     neighborhood_name administritive_area           city  \
# 1412   900000.0                 Dirab              Riyadh   South Riyadh
# 1413   950000.0              Al Awali              Riyadh      Al Riyadh
# 1414  1350000.0  Abhur Ash Shamaliyah              Makkah         Jeddah
# 1415  1600000.0               Al Arid              Riyadh   North Riyadh
# 1416  1850000.0             Al Amanah              Riyadh   North Riyadh
#
#       rooms  bathrooms    sqm  elevator  bool  driver  garden
# 1412      3          4  400.0         0     0       0       0
# 1413      5          6  210.0         0     0       0       0
# 1414      6          6  270.0         1     0       0       1
# 1415      4          6  312.0         1     0       0       0
# 1416      4          5  375.0         0     0       0       0

# %%
df.shape
# Out:
# (1417, 11)

# %%
df.dtypes
# Out:
# price                  float64
# neighborhood_name       object
# administritive_area     object
# city                    object
# rooms                    int64
# bathrooms                int64
# sqm                    float64
# elevator                 int64
# bool                     int64
# driver                   int64
# garden                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   price                1417 non-null   float64
#  1   neighborhood_name    1417 non-null   object
#  2   administritive_area  1396 non-null   object
#  3   city                 1417 non-null   object
#  4   rooms                1417 non-null   int64
#  5   bathrooms            1417 non-null   int64
#  6   sqm                  1417 non-null   float64
#  7   elevator             1417 non-null   int64
#  8   bool                 1417 non-null   int64
#  9   driver               1417 non-null   int64
#  10  garden               1417 non-null   int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 121.9+ KB

# %%
df.describe()
# Out:
#               price        rooms    bathrooms            sqm     elevator  \
# count  1.417000e+03  1417.000000  1417.000000    1417.000000  1417.000000
# mean   1.953098e+06     4.708539     5.143260     917.824277     0.220889
# std    5.369451e+06     1.198701     1.341935   14678.147391     0.446156
# min    1.110000e+02     1.000000     1.000000      22.000000     0.000000
# 25%    1.050000e+06     4.000000     4.000000     268.000000     0.000000
# 50%    1.300000e+06     5.000000     5.000000     312.000000     0.000000
# 75%    1.750000e+06     5.000000     6.000000     390.000000     0.000000
# max    1.600000e+08     7.000000     7.000000  420000.000000     4.000000
#
#               bool       driver       garden
# count  1417.000000  1417.000000  1417.000000
# mean      0.139026     0.148200     0.035286
# std       0.377334     0.361336     0.192067
# min       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000
# ...

# %%
df.describe(include = 'object')
# Out:
#        neighborhood_name administritive_area          city
# count               1417                1396          1417
# unique               123                   2            13
# top             Ar Rimal              Riyadh   East Riyadh
# freq                 268                1019           454

# %%
df['price'].max()
# Out:
# 160000000.0

# %%
df['rooms'].min()
# Out:
# 1

# %%
df['bathrooms'].mean()
# Out:
# 5.143260409315455

# %%
df.isnull()
# Out:
#       price  neighborhood_name  administritive_area   city  rooms  bathrooms  \
# 0     False              False                False  False  False      False
# 1     False              False                False  False  False      False
# 2     False              False                False  False  False      False
# 3     False              False                False  False  False      False
# 4     False              False                False  False  False      False
# ...     ...                ...                  ...    ...    ...        ...
# 1412  False              False                False  False  False      False
# 1413  False              False                False  False  False      False
# 1414  False              False                False  False  False      False
# 1415  False              False                False  False  False      False
# 1416  False              False                False  False  False      False
#
#         sqm  elevator   bool  driver  garden
# ...

# %%
df.isnull().sum()
# Out:
# price                   0
# neighborhood_name       0
# administritive_area    21
# city                    0
# rooms                   0
# bathrooms               0
# sqm                     0
# elevator                0
# bool                    0
# driver                  0
# garden                  0
# dtype: int64

# %%
df[df['administritive_area'].isnull()]
# Out:
#            price     neighborhood_name administritive_area             city  \
# 122    1350000.0               Al Lulu                 NaN        Al Khubar
# 203     850000.0              Al Amwaj                 NaN        Al Khubar
# 204     900000.0               Al Lulu                 NaN        Al Khubar
# 217    1900000.0              Al Hamra                 NaN        Ad Dammam
# 218    3300000.0  Ash Shati Ash Sharqi                 NaN        Ad Dammam
# 402    2700000.0             Ishbiliya                 NaN        Al Khubar
# 403    2350000.0             Ishbiliya                 NaN        Al Khubar
# 423    1000000.0   Al Musa Subdivision                 NaN   Khamis Mushayt
# 588    1550000.0             Ishbiliya                 NaN        Al Khubar
# 593    4000000.0                  Uhud                 NaN        Ad Dammam
# 903     850000.0             As Sawari                 NaN        Al Khubar
# ...

# %%
df[df['administritive_area'].notnull()]
# Out:
#           price     neighborhood_name administritive_area           city  \
# 0     1300000.0           Al Munsiyah              Riyadh    East Riyadh
# 1     2500000.0             Al Murjan              Makkah         Jeddah
# 2     1300000.0              Ar Rimal              Riyadh    East Riyadh
# 3     1550000.0            Az Zomorod              Makkah         Jeddah
# 4     1000000.0             Ash Shifa              Riyadh   South Riyadh
# ...         ...                   ...                 ...            ...
# 1412   900000.0                 Dirab              Riyadh   South Riyadh
# 1413   950000.0              Al Awali              Riyadh      Al Riyadh
# 1414  1350000.0  Abhur Ash Shamaliyah              Makkah         Jeddah
# 1415  1600000.0               Al Arid              Riyadh   North Riyadh
# 1416  1850000.0             Al Amanah              Riyadh   North Riyadh
#
#       rooms  bathrooms    sqm  elevator  bool  driver  garden
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1412    False
# 1413    False
# 1414    False
# 1415    False
# 1416    False
# Length: 1417, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 160

# %%
df[df.duplicated()]
# Out:
#           price   neighborhood_name administritive_area           city  rooms  \
# 9      950000.0           Ar Riyadh              Makkah         Jeddah      3
# 108   3000000.0  Abhur Al Janubiyah              Makkah         Jeddah      4
# 109   1300000.0           Al Yaqoot              Makkah         Jeddah      4
# 120   4200000.0            Al Malqa              Riyadh   North Riyadh      7
# 121   1800000.0           An Narjis              Riyadh   North Riyadh      4
# ...         ...                 ...                 ...            ...    ...
# 1363  1280000.0            Ar Rimal              Riyadh    East Riyadh      6
# 1374   950000.0                Uhud              Riyadh   South Riyadh      4
# 1381  1180000.0              Tuwaiq              Riyadh    West Riyadh      5
# 1382  1550000.0            Ar Rimal              Riyadh    East Riyadh      6
# 1400  1500000.0        Al Qadisiyah              Riyadh    East Riyadh      6
#
# ...

# %%
df.columns
# Out:
# Index(['price', 'neighborhood_name', 'administritive_area', 'city', 'rooms',
#        'bathrooms', 'sqm', 'elevator', 'bool', 'driver', 'garden'],
#       dtype='object')

# %%
Q1_sqm = df['sqm'].quantile(0.25)
Q3_sqm = df['sqm'].quantile(0.75)
IQR_sqm = Q3_sqm - Q1_sqm

outliers_sqm = df[
    (df['sqm'] < Q1_sqm - 1.5 * IQR_sqm)|
    (df['sqm'] > Q3_sqm + 1.5 * IQR_sqm)
]
outliers_sqm
# Out:
#            price          neighborhood_name administritive_area  \
# 38     4000000.0                     Taibah              Makkah
# 40     6500000.0                    An Naim              Makkah
# 43     3500000.0  Al Amir Fawaz Ash Shamaly              Makkah
# 61     2700000.0                  Ash Shifa              Riyadh
# 91    57000000.0                   Az Zahra              Makkah
# ...          ...                        ...                 ...
# 1351   4400000.0                   Al Malqa              Riyadh
# 1360   4900000.0                   Al Malqa              Riyadh
# 1365   2960000.0                   Az Zahra              Makkah
# 1366   4000000.0                 Ash Sheraa              Makkah
# 1411   4600000.0                   Al Malqa              Riyadh
#
#                city  rooms  bathrooms     sqm  elevator  bool  driver  garden
# 38           Jeddah      5          7   895.0         0     1       0       0
# ...

# %% [raw]
# # Consistency Checks

# %%
df[df['bathrooms'] > df ['rooms']]
# Out:
#           price neighborhood_name administritive_area           city  rooms  \
# 0     1300000.0       Al Munsiyah              Riyadh    East Riyadh      4
# 5     2200000.0           An Naim              Makkah         Jeddah      5
# 6     2500000.0         An Nahdah              Makkah         Jeddah      5
# 11    1350000.0          Ar Rimal              Riyadh    East Riyadh      5
# 12     880000.0        Al Ghoroub              Riyadh    West Riyadh      5
# ...         ...               ...                 ...            ...    ...
# 1411  4600000.0          Al Malqa              Riyadh   North Riyadh      5
# 1412   900000.0             Dirab              Riyadh   South Riyadh      3
# 1413   950000.0          Al Awali              Riyadh      Al Riyadh      5
# 1415  1600000.0           Al Arid              Riyadh   North Riyadh      4
# 1416  1850000.0         Al Amanah              Riyadh   North Riyadh      4
#
#       bathrooms    sqm  elevator  bool  driver  garden
# ...

# %%
df[(df['rooms'] >= 6) &( df ['sqm'] <200)]
# Out:
#           price neighborhood_name administritive_area     city  rooms  \
# 1191  9000050.0        Ash Sheraa              Makkah   Jeddah      6
# 1266  9000050.0        Ash Sheraa              Makkah   Jeddah      6
#
#       bathrooms   sqm  elevator  bool  driver  garden
# 1191          6  22.0         1     0       0       0
# 1266          6  22.0         1     0       0       0

# %% [raw]
# # Data Cleaning

# %%
df = df.copy()

# %%
df['administritive_area'] = df['administritive_area'].fillna('Unknown')

# %%
df['administritive_area'].isnull().sum()
# Out:
# 0

# %%
df = df.drop (df[(df['rooms'] >= 6) & ( df ['sqm'] <200)].index)

# %%
df.dtypes
# Out:
# price                  float64
# neighborhood_name       object
# administritive_area     object
# city                    object
# rooms                    int64
# bathrooms                int64
# sqm                    float64
# elevator                 int64
# bool                     int64
# driver                   int64
# garden                   int64
# dtype: object

# %%
print(df.shape)
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# (1256, 11)
# price                  0
# neighborhood_name      0
# administritive_area    0
# city                   0
# rooms                  0
# bathrooms              0
# sqm                    0
# elevator               0
# bool                   0
# driver                 0
# garden                 0
# dtype: int64
# 0

# %% [raw]
# # Data Analysis & Visualization

# %%
# Histogram

df['price'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
# ScatterPlot sqm vs price 

plt.scatter(df['sqm'], df['price'])
plt.xlabel('sqm')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
# Boxplot

df.boxplot(column='price' , by='city',rot=45)
# Out:
# <AxesSubplot:title={'center':'price'}, xlabel='city'>

# %%
# Bar Chart

df.groupby('city')['price'].mean().sort_values(ascending = False ).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='city'>

# %%
plt.scatter(df['rooms'], df ['price'])

# %%
df.groupby('elevator')['price'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='elevator'>

# %%
df.to_csv('Villas Real Estate Price.csv', index=False)
df
# Out:
#           price     neighborhood_name administritive_area           city  \
# 0     1300000.0           Al Munsiyah              Riyadh    East Riyadh
# 1     2500000.0             Al Murjan              Makkah         Jeddah
# 2     1300000.0              Ar Rimal              Riyadh    East Riyadh
# 3     1550000.0            Az Zomorod              Makkah         Jeddah
# 4     1000000.0             Ash Shifa              Riyadh   South Riyadh
# ...         ...                   ...                 ...            ...
# 1412   900000.0                 Dirab              Riyadh   South Riyadh
# 1413   950000.0              Al Awali              Riyadh      Al Riyadh
# 1414  1350000.0  Abhur Ash Shamaliyah              Makkah         Jeddah
# 1415  1600000.0               Al Arid              Riyadh   North Riyadh
# 1416  1850000.0             Al Amanah              Riyadh   North Riyadh
#
#       rooms  bathrooms    sqm  elevator  bool  driver  garden
# ...
